# %% [markdown]
# <a href="https://colab.research.google.com/github/cezarcorrea/cezarcorrea-Deteccao-Gato-Cachorro/blob/main/detec%C3%A7%C3%A3o_gato_cachorro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conecta o Google Colab ao seu Google Drive.
from google.colab import drive
drive.mount('/content/drive')

# Navega até o diretório do seu projeto no Drive.
# Se a pasta não existir, você precisa criá-la manualmente no Drive primeiro.
# %cd /content/drive/MyDrive/meu_projeto_animais2

# Remove o repositório existente para evitar erros de clonagem.
# !rm -rf yolov5

# Clona o repositório do YOLOv5 da Ultralytics.
# !git clone https://github.com/ultralytics/yolov5.git

# Entra na pasta do YOLOv5 para instalar as dependências.
# %cd yolov5

# Instala todas as dependências do YOLOv5.
# !pip install -r requirements.txt
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/meu_projeto_animais2
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17564, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 17564 (delta 33), reused 7 (delta 7), pack-reused 17510 (from 4)
# Receiving objects: 100% (17564/17564), 16.69 MiB | 10.77 MiB/s, done.
# Resolving deltas: 100% (12031/12031), done.
# Updating files: 100% (146/146), done.
# /content/drive/MyDrive/meu_projeto_animais2/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.9 MB/s eta 0:00:00
# ...

# %%
# %%writefile ../data.yaml
# # Caminhos para as pastas de treino e validação
# train: '/content/drive/MyDrive/meu_projeto_animais2/data/images/train'
# val: '/content/drive/MyDrive/meu_projeto_animais2/data/images/val'
#
# # Número de classes e nomes
# nc: 2
# names: ['cat', 'dog']
# Out:
# Writing ../data.yaml

# %%
# Volta para o diretório raiz do projeto para que o comando de treino encontre o arquivo data.yaml.
# %cd ..

# Inicia o treinamento.
# !python yolov5/train.py --img 640 --batch 16 --epochs 20 --data data.yaml --weights yolov5s.pt --cache
# Out:
# /content/drive/MyDrive/meu_projeto_animais2
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-08-29 23:37:09.671666: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# Navega para a pasta do YOLOv5 para executar o script de detecção.
# %cd yolov5

# Encontra a pasta de treinamento mais recente (exp, exp2, etc.).
import os
import glob

latest_exp_folder = max(glob.glob('runs/train/exp*'), key=os.path.getmtime)

# Define o caminho completo para o modelo treinado.
weights_path = os.path.join(latest_exp_folder, 'weights', 'best.pt')

# Executa o comando de detecção.
# !python detect.py --source /content/drive/MyDrive/meu_projeto_animais2/teste/image.jpg --weights {weights_path} --conf 0.4 --name result_exp

print(f"Detecção concluída! A imagem com os resultados foi salva em: {os.path.join(latest_exp_folder, 'sua_imagem_de_teste.jpg')}")
# Out:
# /content/drive/MyDrive/meu_projeto_animais2/yolov5
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/meu_projeto_animais2/teste/image.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=result_exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/meu_projeto_animais2/teste/image.jpg: 384x640 (no detections), 408.9ms
# Speed: 2.5ms pre-process, 408.9ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# ...
